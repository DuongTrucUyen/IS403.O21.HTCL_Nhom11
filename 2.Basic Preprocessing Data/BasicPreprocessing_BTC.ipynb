# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Đọc tệp CSV và lưu dữ liệu vào một DataFrame
df = pd.read_csv('BTC.csv')
df = df[['Close']]
#In ra nội dung của DataFrame
print(df)
# Out:
#              Close
# 0      3859.583740
# 1      3864.415039
# 2      3847.175781
# 3      3761.557129
# 4      3896.375000
# ...            ...
# 1899  61448.394530
# 1900  62901.449220
# 1901  61552.789060
# 1902  66267.492190
# 1903  65231.582030
#
# [1904 rows x 1 columns]

# %%
#In ra các thống kê mô tả của DataFrame
print(df.describe())
# Out:
#               Close
# count   1904.000000
# mean   27593.794400
# std    17608.383346
# min     3761.557129
# 25%    10406.202390
# 50%    25832.785155
# 75%    40890.010745
# max    73083.500000

# %%
#Kiểm tra missing data
df.isna().sum()
# Out:
# Close    0
# dtype: int64

# %% [markdown]
# *-> Không có missing data*

# %%
# Vẽ biểu đồ histogram
plt.hist(df)
# Hiển thị biểu đồ
plt.show()

# %%
#Vẽ biểu đồ box plot
plt.boxplot(df)
#Hiển thị biểu đồ
plt.show()

# %%
df.plot()
# Out:
# <Axes: >
